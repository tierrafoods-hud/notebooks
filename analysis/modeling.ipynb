# %%
import pandas as pd

country_name = 'Guatemala'
dataset_path = f'outputs/20241127/{country_name}_wosis/{country_name}_wosis_merged.csv'

# load datasets
dataset = pd.read_csv(dataset_path)

# check dataset
dataset.head()
# Out:
#    longitude  latitude  upper_depth  lower_depth  bdfi33_avg  bdfiod_avg  \
# 0 -90.183334     13.85          0.0         19.0    1.476667        1.41
# 1 -91.300000     14.20          0.0         21.0    1.740000        1.67
# 2 -90.300000     14.20          0.0         25.0    1.226667        1.24
# 3 -90.300000     14.20          0.0         25.0    1.226667        1.24
# 4 -90.300000     14.20          0.0         25.0    1.226667        1.24
#
#    bdwsod_avg  cecph7_avg  cfgr_avg  cfvo_avg  ...  phaq_avg  phca_avg  \
# 0        1.42        28.6       1.0       1.0  ...       6.9       6.7
# 1        1.67        20.5       0.0       0.0  ...       6.4       6.4
# 2        1.31        41.8      12.0       4.0  ...       6.1       5.6
# 3        1.31        41.8      12.0       4.0  ...       6.1       5.6
# 4        1.31        41.8      12.0       4.0  ...       6.1       5.6
#
#    phetb1_avg  phkc_avg  phnf_avg  phprtn_avg  sand_avg  silt_avg  tceq_avg  \
# 0         NaN       NaN       NaN        34.0      30.0      43.0       NaN
# 1         NaN       NaN       NaN        25.0      38.3      52.7       NaN
# 2         NaN       NaN       NaN        59.0      33.5      32.6       0.0
# 3         NaN       NaN       NaN        59.0      33.5      33.0       0.0
# 4         NaN       NaN       NaN        59.0      33.0      32.6       0.0
#
#    totc_avg
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 26 columns]

# %%
import matplotlib.pyplot as plt

# plot histogram of values
dataset.hist(bins=50, figsize=(20, 15))
plt.title(f'{country_name} WOSIS Merged Dataset')
plt.show()

# %%
import seaborn as sns

# plot missing values
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis')
plt.title(f'{country_name} WOSIS Merged Dataset Missing Values')
plt.show()
